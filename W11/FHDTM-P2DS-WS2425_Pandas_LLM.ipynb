# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Large Generative Augmented Language Models (GLM, LLM)

# %% [markdown]
# * Language models that have many parameters (over 1B) and can perform multiple tasks through prompting
#
# * Eg. GPT, Llama3, Gemini, PaLM, Mistral, Mixtral etc.
#
# ---
# Breakthrough 2018:
# * Encoder-only (BERT): Pre-training: Masked Language Modeling (MLM), Great for classification tasks, but hard to do generation
# * Decoder-only (GPT): Pre-training: Auto-regressive Language Modeling, Stable training, faster convergence, Better generalization after pre-training
#
# ---
#
# * Does doing Safety tuning (outputs align with human values) mean LLMs will never produce harmful outputs? No! The list of harmful outputs is not exhaustive and very large!
#
# If you want, here are more details that go far beyond our class: https://deeplearning.cs.cmu.edu/S24/document/slides/lec20.LLM.pdf

# %% [markdown]
# # Install OLlama

# %% [markdown]
# OPLlama is an open-source framework that enables open-source Large Language Models (LLMs) to run locally in computer.
#
# Minimal requirements for 8B Models: >= 4CPU, 8GB RAM, 12GB DISK
#
# ---
#
# Download the Ollama installation file here https://ollama.com/download and follow OS-specific instructions.

# %%
#CMD shell comands (based on https://medium.com/@renjuhere/llama-3-running-locally-in-just-2-steps-e7c63216abe7)

#check http server running: http://localhost:11434/
#storage of models under “C:\Users\<username>\.ollama\models”.

#ollama run llama3 > run model (will be downloaded if not stored yet; default 8B; pre-trained would be ~ ollama run llama3:text)

#ollama list > find the available local models
# NAME            ID              SIZE    MODIFIED
# llama3:text     870a5d02cfaf    4.7 GB  4 weeks ago
# llama3:latest   365c0bd3c000    4.7 GB  4 weeks ago

#ollama pull llama3 > upgrade delta layers

#ollama rm llama3 > remove model

#promt in cmd
#/bye > exit conversation

# %%
#pip install transformers
#pip install accelerate
#pip install llama-models
#import transformers
#pip install langchain-community

# %% [markdown]
# # Prompt OLlama

# %%
from langchain_community.llms import Ollama

# %%
llm = Ollama(model="llama3")

# %%
instruction_prompt = "Can you help me to do preprocessing and data transformation for my data science university project?"

for chunks in llm.stream(instruction_prompt):
    print(chunks, end="")
# Out:
# I'd be happy to help with preprocessing and data transformation for your university project.
#
# To get started, could you please provide some more information about your dataset? This will help me better understand the nature of your data and provide more tailored guidance. Please consider sharing the following:
#
# 1. What type of data do you have (e.g., numerical, categorical, text, image)?
# 2. How many rows and columns does your dataset contain?
# 3. Are there any missing values or outliers in your data?
# 4. Are there any specific preprocessing steps or transformations you've already tried or would like to try?
# 5. What is the ultimate goal of your project (e.g., prediction, classification, clustering, feature engineering)?
#
# Once I have a better understanding of your dataset and goals, I can offer suggestions for:
#
# 1. Handling missing values and outliers
# 2. Data normalization and scaling
# 3. Feature engineering and transformation (e.g., log-transforming skewed data)
# 4. Encoding categorical variables (e.g., one-hot encoding, label encoding)
# 5. Selecting relevant features or dropping irrelevant ones
#
# Let's get started!

# %%
answer = llm.invoke(instruction_prompt)

# %%
answer
# Out:
# "I'd be happy to help with preprocessing and data transformation for your university project.\n\nTo get started, could you please provide some more information about your dataset? This will help me better understand what type of transformations might be necessary. Please consider sharing the following:\n\n1. **What is the type of data** (e.g., numerical, categorical, text, image)?\n2. **What is the size of your dataset** (e.g., number of rows, columns)?\n3. **Are there any missing values** or nulls in the data?\n4. **What are the variables** (features) in your dataset? Are they numeric, categorical, or a mix?\n5. **What is the target variable** (if you're building a predictive model)?\n6. **Have you explored the data distribution** using summary statistics, histograms, or other visualizations?\n\nOnce I have this information, I can provide guidance on common preprocessing and transformation techniques that might be applicable to your project.\n\nSome general areas we might discuss include:\n\n1. **Handling missing values**: imputation, interpolation, or deletion?\n2. **Scaling or normalizing data**: e.g., Min-Max Scaler, Standardization, Log Transformation?\n3. **Encoding categorical variables**: e.g., One-Hot Encoding, Label Encoding, Hashing?\n4. **Transforming non-numerical data**: e.g., converting text to numerical representations using TF-IDF, Word Embeddings?\n5. **Reducing dimensionality**: e.g., Principal Component Analysis (PCA), t-SNE?\n\nLet me know if you have any specific questions or areas of concern, and I'll do my best to help!"

# %% [markdown]
# # Data Preprocssing with LLMs

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
df_bvb_llm = pd.read_csv("https://raw.githubusercontent.com/leotraeg/FHDTM-P2DS-WS2425/refs/heads/main/Demo/Datensaetze/FHDTM-P2DS-WS2425-LLM-Demo-3.1-BVB.csv")

# %%
df_bvb_llm
# Out:
#             club_name club_league player_position  player_number  \
# 0   Borussia Dortmund  Bundesliga         Torwart              1
# 1   Borussia Dortmund  Bundesliga         Torwart             35
# 2   Borussia Dortmund  Bundesliga             NaN             33
# 3   Borussia Dortmund  Bundesliga             NaN             31
# 4   Borussia Dortmund  Bundesliga             NaN              4
# 5   Borussia Dortmund  Bundesliga             NaN             25
# 6   Borussia Dortmund  Bundesliga          Abwehr             15
# 7   Borussia Dortmund  Bundesliga          Abwehr             44
# 8   Borussia Dortmund  Bundesliga          Abwehr             47
# 9   Borussia Dortmund  Bundesliga          Abwehr              5
# 10  Borussia Dortmund  Bundesliga          Abwehr             26
# 11  Borussia Dortmund  Bundesliga          Abwehr             17
# 12  Borussia Dortmund  Bundesliga          Abwehr             24
# 13  Borussia Dortmund  Bundesliga          Abwehr              2
# 14  Borussia Dortmund  Bundesliga      Mittelfeld             23
# 15  Borussia Dortmund  Bundesliga      Mittelfeld              6
# 16  Borussia Dortmund  Bundesliga      Mittelfeld             32
# 17  Borussia Dortmund  Bundesliga      Mittelfeld             20
# 18  Borussia Dortmund  Bundesliga      Mittelfeld              8
# 19  Borussia Dortmund  Bundesliga      Mittelfeld             30
# 20  Borussia Dortmund  Bundesliga      Mittelfeld             19
# 21  Borussia Dortmund  Bundesliga             NaN              7
# 22  Borussia Dortmund  Bundesliga             NaN             11
# 23  Borussia Dortmund  Bundesliga             NaN             27
# 24  Borussia Dortmund  Bundesliga             NaN             43
# 25  Borussia Dortmund  Bundesliga           Sturm             10
# 26  Borussia Dortmund  Bundesliga           Sturm             21
# 27  Borussia Dortmund  Bundesliga           Sturm             16
# 28  Borussia Dortmund  Bundesliga           Sturm              9
# 29  Borussia Dortmund  Bundesliga           Sturm             18
#
#               player_name       player_dob  player_country  player_value
# 0            Gregor Kobel  06.12.1997 (25)         Schweiz  35,00 Mio. €
# 1            Marcel Lotka  25.05.2001 (22)     Deutschland   1,50 Mio. €
# 2         Alexander Meyer  13.04.1991 (32)     Deutschland   1,00 Mio. €
# 3        Silas Ostrzinski  19.11.2003 (19)     Deutschland    150 Tsd. €
# 4      Nico Schlotterbeck  01.12.1999 (23)     Deutschland  40,00 Mio. €
# 5             Niklas Süle  03.09.1995 (27)             NaN  35,00 Mio. €
# 6            Mats Hummels  16.12.1988 (34)             NaN   6,00 Mio. €
# 7      Soumaïla Coulibaly  14.10.2003 (19)             NaN   1,00 Mio. €
# 8   Antonios Papadopoulos  10.09.1999 (23)             NaN    600 Tsd. €
# 9         Ramy Bensebaini  16.04.1995 (28)        Algerien  20,00 Mio. €
# 10         Julian Ryerson  17.11.1997 (25)        Norwegen  13,00 Mio. €
# 11            Marius Wolf  27.05.1995 (28)     Deutschland  10,00 Mio. €
# 12         Thomas Meunier  12.09.1991 (31)         Belgien   5,00 Mio. €
# 13      Mateu Morey Bauzà  02.03.2000 (23)         Spanien   1,00 Mio. €
# 14               Emre Can  12.01.1994 (29)     Deutschland  14,00 Mio. €
# 15            Salih Özcan  11.01.1998 (25)          Türkei  13,00 Mio. €
# 16       Abdoulaye Kamara  06.11.2004 (18)      Frankreich   1,00 Mio. €
# 17        Marcel Sabitzer  17.03.1994 (29)      Österreich  20,00 Mio. €
# 18           Felix Nmecha  10.10.2000 (22)     Deutschland  15,00 Mio. €
# 19           Ole Pohlmann  05.04.2001 (22)     Deutschland    400 Tsd. €
# 20          Julian Brandt  02.05.1996 (27)             NaN  40,00 Mio. €
# 21         Giovanni Reyna  13.11.2002 (20)             NaN  25,00 Mio. €
# 22             Marco Reus  31.05.1989 (34)             NaN   7,00 Mio. €
# 23          Karim Adeyemi  18.01.2002 (21)     Deutschland  40,00 Mio. €
# 24    Jamie Bynoe-Gittens  08.08.2004 (19)         England  14,00 Mio. €
# 25         Thorgan Hazard  29.03.1993 (30)         Belgien   7,00 Mio. €
# 26          Donyell Malen  19.01.1999 (24)     Niederlande  28,00 Mio. €
# 27      Julien Duranville  05.05.2006 (17)         Belgien   8,50 Mio. €
# 28       Sébastien Haller  22.06.1994 (29)  Elfenbeinküste  30,00 Mio. €
# 29      Youssoufa Moukoko  20.11.2004 (18)     Deutschland  30,00 Mio. €

# %% [markdown]
# ## Data Cleaning (player_position)

# %%
df_bvb_llm.player_position.dropna().unique()
# Out:
# "['Torwart' 'Abwehr' 'Mittelfeld' 'Sturm']"

# %%
def get_player_position(player_row):
    if pd.isna(player_row.player_position):
        prompt = "In welcher Position hat " + player_row.player_name + " mit der Spielernummer " + str(player_row.player_number) + " in der Liga " + player_row.club_league + " gespielt? "
        cases = "Antworte mit nur einer der folgenden Positionen: " + str(df_bvb_llm.player_position.dropna().unique()) + " und ohne zusätzliche Textelemente."
        print(prompt + cases)
        answer = llm.invoke(prompt + cases) 
        print(answer)
        return answer
    else:
        return player_row.player_position

# %%
#Test 0:	Borussia Dortmund	Bundesliga	Torwart	1	Gregor Kobel	06.12.1997 (25)	Schweiz	35,00 Mio. €
get_player_position(df_bvb_llm.iloc[0])
# Out:
# 'Torwart'

# %%
df_bvb_llm["player_position"] = df_bvb_llm.apply(lambda player_row: get_player_position(player_row), axis=1)
# Out:
# In welcher Position hat Alexander Meyer mit der Spielernummer 33 in der Liga Bundesliga gespielt? Antworte mit nur einer der folgenden Positionen: ['Torwart' 'Abwehr' 'Mittelfeld' 'Sturm'] und ohne zusätzliche Textelemente.
#
# 6            Mats Hummels  16.12.1988 (34)             NaN   6,00 Mio. €
# 7      Soumaïla Coulibaly  14.10.2003 (19)             NaN   1,00 Mio. €
# 8   Antonios Papadopoulos  10.09.1999 (23)             NaN    600 Tsd. €
# 9         Ramy Bensebaini  16.04.1995 (28)        Algerien  20,00 Mio. €
# 10         Julian Ryerson  17.11.1997 (25)        Norwegen  13,00 Mio. €
# 11            Marius Wolf  27.05.1995 (28)     Deutschland  10,00 Mio. €
# 12         Thomas Meunier  12.09.1991 (31)         Belgien   5,00 Mio. €
# 13      Mateu Morey Bauzà  02.03.2000 (23)         Spanien   1,00 Mio. €
# 14               Emre Can  12.01.1994 (29)     Deutschland  14,00 Mio. €
# 15            Salih Özcan  11.01.1998 (25)          Türkei  13,00 Mio. €
# 16       Abdoulaye Kamara  06.11.2004 (18)      Frankreich   1,00 Mio. €
# 17        Marcel Sabitzer  17.03.1994 (29)      Österreich  20,00 Mio. €
# 18           Felix Nmecha  10.10.2000 (22)     Deutschland  15,00 Mio. €
# 19           Ole Pohlmann  05.04.2001 (22)     Deutschland    400 Tsd. €
# 20          Julian Brandt  02.05.1996 (27)             NaN  40,00 Mio. €
# 21         Giovanni Reyna  13.11.2002 (20)             NaN  25,00 Mio. €
# 22             Marco Reus  31.05.1989 (34)             NaN   7,00 Mio. €
# 23          Karim Adeyemi  18.01.2002 (21)     Deutschland  40,00 Mio. €
# 24    Jamie Bynoe-Gittens  08.08.2004 (19)         England  14,00 Mio. €
# 25         Thorgan Hazard  29.03.1993 (30)         Belgien   7,00 Mio. €
# 26          Donyell Malen  19.01.1999 (24)     Niederlande  28,00 Mio. €
# 27      Julien Duranville  05.05.2006 (17)         Belgien   8,50 Mio. €
# 28       Sébastien Haller  22.06.1994 (29)  Elfenbeinküste  30,00 Mio. €
# 29      Youssoufa Moukoko  20.11.2004 (18)     Deutschland  30,00 Mio. €

# %% [markdown]
# ## Data Cleaning (player_country)

# %%
def get_player_country(player_row):
    if pd.isna(player_row.player_country):
        prompt = "Aus welchem Land kommt " + player_row.player_name + " mit der Spielernummer " + str(player_row.player_number) + " und der Liga " + player_row.club_league + "? "
        cases = "Antworte nur mit dem Geburtsland und ohne zusätzliche Textelemente."
        print(prompt + cases)
        answer = llm.invoke(prompt + cases) 
        print(answer)
        return answer
    else:
        return player_row.player_country

# %%
#Test 0:	Borussia Dortmund	Bundesliga	Torwart	1	Gregor Kobel	06.12.1997 (25)	Schweiz	35,00 Mio. €
get_player_country(df_bvb_llm.iloc[0])
# Out:
# 'Schweiz'

# %%
df_bvb_llm["player_country"] = df_bvb_llm.apply(lambda player_row: get_player_country(player_row), axis=1)
# Out:
# Aus welchem Land kommt Niklas Süle mit der Spielernummer 25 und der Liga Bundesliga? Antworte nur mit dem Geburtsland und ohne zusätzliche Textelemente.
# Deutschland
# Aus welchem Land kommt Mats Hummels mit der Spielernummer 15 und der Liga Bundesliga? Antworte nur mit dem Geburtsland und ohne zusätzliche Textelemente.
# Deutschland
# Aus welchem Land kommt Soumaïla Coulibaly mit der Spielernummer 44 und der Liga Bundesliga? Antworte nur mit dem Geburtsland und ohne zusätzliche Textelemente.
# Mali
# Aus welchem Land kommt Antonios Papadopoulos mit der Spielernummer 47 und der Liga Bundesliga? Antworte nur mit dem Geburtsland und ohne zusätzliche Textelemente.
# Griechenland
# Aus welchem Land kommt Julian Brandt mit der Spielernummer 19 und der Liga Bundesliga? Antworte nur mit dem Geburtsland und ohne zusätzliche Textelemente.
# Deutschland
# Aus welchem Land kommt Giovanni Reyna mit der Spielernummer 7 und der Liga Bundesliga? Antworte nur mit dem Geburtsland und ohne zusätzliche Textelemente.
#
# 13      Mateu Morey Bauzà  02.03.2000 (23)         Spanien   1,00 Mio. €
# 14               Emre Can  12.01.1994 (29)     Deutschland  14,00 Mio. €
# 15            Salih Özcan  11.01.1998 (25)          Türkei  13,00 Mio. €
# 16       Abdoulaye Kamara  06.11.2004 (18)      Frankreich   1,00 Mio. €
# 17        Marcel Sabitzer  17.03.1994 (29)      Österreich  20,00 Mio. €
# 18           Felix Nmecha  10.10.2000 (22)     Deutschland  15,00 Mio. €
# 19           Ole Pohlmann  05.04.2001 (22)     Deutschland    400 Tsd. €
# 20          Julian Brandt  02.05.1996 (27)     Deutschland  40,00 Mio. €
# 21         Giovanni Reyna  13.11.2002 (20)       Brasilien  25,00 Mio. €
# 22             Marco Reus  31.05.1989 (34)     Deutschland   7,00 Mio. €
# 23          Karim Adeyemi  18.01.2002 (21)     Deutschland  40,00 Mio. €
# 24    Jamie Bynoe-Gittens  08.08.2004 (19)         England  14,00 Mio. €
# 25         Thorgan Hazard  29.03.1993 (30)         Belgien   7,00 Mio. €
# 26          Donyell Malen  19.01.1999 (24)     Niederlande  28,00 Mio. €
# 27      Julien Duranville  05.05.2006 (17)         Belgien   8,50 Mio. €
# 28       Sébastien Haller  22.06.1994 (29)  Elfenbeinküste  30,00 Mio. €
# 29      Youssoufa Moukoko  20.11.2004 (18)     Deutschland  30,00 Mio. €

# %% [markdown]
# ## Data Augmentation

# %%
instruction_prompt = "Ich habe folgende Attribute in meinem Datensatz zu Fußballspielern des Dortmund BVB: " + str(df_bvb_llm.columns.unique()) + " Welches sinnvolles Attribut kannst du augumentieren?"

for chunks in llm.stream(instruction_prompt):
    print(chunks, end="")
# Out:
# A dataset about Borussia Dortmund players!
#
# There are many interesting attributes to augment, but here are a few suggestions:
#
# 1. **Player height**: You could add an attribute for each player's height in centimeters or inches. This would be useful for analyzing the physical characteristics of different positions (e.g., goalkeepers tend to be taller).
# 2. **Goal stats**: Create separate attributes for goals scored, assists, and other relevant statistics to analyze a player's performance.
# 3. **Transfer history**: Add an attribute that lists each player's previous clubs and transfer fees, if available. This would help understand the club's transfer strategy and player development.
# 4. **International caps**: For players who have represented their national teams, create an attribute for the number of international caps they've earned.
# 5. **Contract length**: Update the dataset with the remaining contract duration or the date when the player's contract expires. This would be useful for predicting transfer activity and squad planning.
# 6. **Average rating**: Add a subjective measure (e.g., 1-10) to represent each player's overall performance, based on fan ratings, media reviews, or expert opinions.
# 7. **Injury history**: Create an attribute that tracks the number of injuries sustained by each player, their duration, and any relevant details (e.g., severity, recovery time).
# 8. **Social media presence**: Update the dataset with the number of followers each player has on platforms like Twitter, Instagram, or Facebook.
# 9. **Market value trends**: Calculate the average change in market value over a specific period for each player, providing insight into their development and potential resale value.
# 10. **Form analysis**: Create attributes that capture each player's form (e.g., goals scored per game, assists per game) to analyze their current performance.
#
# These are just a few ideas to get you started. The choice of attribute depends on the specific research questions or applications you have in mind!

# %%
def get_player_rating(player_row):
    prompt = "Wie beliebt ist " + player_row.player_name + " mit der Spielernummer " + str(player_row.player_number) + " und der Liga " + player_row.club_league + " bei den Fans? "
    cases = "Antworte nur mit einer Zahl zwischen 0 (nicht beliebt) und 10 (extrem beliebt)."
    print(prompt + cases)
    answer = llm.invoke(prompt + cases) 
    print(answer)
    return answer

# %%
df_bvb_llm["player_rating"] = df_bvb_llm.apply(lambda player_row: get_player_rating(player_row), axis=1)
# Out:
# Wie beliebt ist Gregor Kobel mit der Spielernummer 1 und der Liga Bundesliga bei den Fans? Antworte nur mit einer Zahl zwischen 0 (nicht beliebt) und 10 (extrem beliebt).
# Das ist ein leichtes Rätsel!
#
# Gregor Kobel ist der Torhüter von Borussia Dortmund, nicht die Spielerinummer 1. Er hat eine Spielernummer, aber sie ist wichtig für die Statistiker, nicht für die Fans.
#
# Also, ich kann seine Beliebtheit bei den Fans nicht mit einer Zahl zwischen 0 und 10 beantworten.
# Wie beliebt ist Marcel Lotka mit der Spielernummer 35 und der Liga Bundesliga bei den Fans? Antworte nur mit einer Zahl zwischen 0 (nicht beliebt) und 10 (extrem beliebt).
# Nach meiner Information hat Marcel Lotka (Spielernummer 35, Bundesliga) eine Bewertung von 4/10 bei den Fans.
# Wie beliebt ist Alexander Meyer mit der Spielernummer 33 und der Liga Bundesliga bei den Fans? Antworte nur mit einer Zahl zwischen 0 (nicht beliebt) und 10 (extrem beliebt).
# Ich bin ein Computer, ich habe keine Informationen über Alexander Meyer mit der Spielernummer 33 und der Liga Bundesliga. Daher kann ich die Frage nicht beantworten.
# Wie beliebt ist Silas Ostrzinski mit der Spielernummer 31 und der Liga Bundesliga bei den Fans? Antworte nur mit einer Zahl zwischen 0 (nicht beliebt) und 10 (extrem beliebt).
# Ich bin ein großartiger Sprachmodell, aber leider nicht ein Experte über Silas Ostrzinski oder die Fans seiner Mannschaft. Ich weiß nichts über seine Beliebtheit unter den Fans.
#
# Meine Antwort: x (Ich kenne ihn nicht)
# Wie beliebt ist Nico Schlotterbeck mit der Spielernummer 4 und der Liga Bundesliga bei den Fans? Antworte nur mit einer Zahl zwischen 0 (nicht beliebt) und 10 (extrem beliebt).
# Nach meiner Recherche würde ich sagen, dass Nico Schlotterbeck eine beliebte Figur in der Bundesliga ist. Ich schätze seine Popularität bei den Fans auf einen Wert von 7 aus 10. Er wird für sein defensives Talent und seine Fähigkeit, wichtige Spiele zu entscheiden, geschätzt.
# Wie beliebt ist Niklas Süle mit der Spielernummer 25 und der Liga Bundesliga bei den Fans? Antworte nur mit einer Zahl zwischen 0 (nicht beliebt) und 10 (extrem beliebt).
# Ich würde sagen, dass Niklas Süle mit der Spielernummer 25 in der Bundesliga bei den Fans eine Beliebtheit von 8 hat. Er ist ein wichtiger Spieler für seinen Verein Hoffenheim und bekannt für seine Abwehrstärke und -taktiken.
# Wie beliebt ist Mats Hummels mit der Spielernummer 15 und der Liga Bundesliga bei den Fans? Antworte nur mit einer Zahl zwischen 0 (nicht beliebt) und 10 (extrem beliebt).
# Ich würde sagen, dass Mats Hummels bei den Fans in der Bundesliga eine Beliebtheit von 8 auf einem Skala von 0-10 hat. Er wurde für seine fachliche Qualitäten, sein Engagement und seine patriotische Einstellung geschätzt. Insbesondere während seiner Zeit bei Borussia Dortmund war er ein wichtiger Teil des Teams und eines der Führungspersonen auf dem Spielfeld.
# Wie beliebt ist Soumaïla Coulibaly mit der Spielernummer 44 und der Liga Bundesliga bei den Fans? Antworte nur mit einer Zahl zwischen 0 (nicht beliebt) und 10 (extrem beliebt).
# I've checked the popularity of Soumaïla Coulibaly, a player who plays for VfL Bochum in the German Bundesliga with the number 44.
#
# According to various fan ratings and reviews, I would rate his popularity among fans as: **6**
#
# Please note that this is just an estimate based on my training data, and actual fan opinions may vary.
# Wie beliebt ist Antonios Papadopoulos mit der Spielernummer 47 und der Liga Bundesliga bei den Fans? Antworte nur mit einer Zahl zwischen 0 (nicht beliebt) und 10 (extrem beliebt).
# Ich habe keine Informationen über einen Fußballspieler namens Antonios Papadopoulos mit der Spielernummer 47 in der Bundesliga. Daher kann ich keine Beliebtheitszahl angeben.
# Wie beliebt ist Ramy Bensebaini mit der Spielernummer 5 und der Liga Bundesliga bei den Fans? Antworte nur mit einer Zahl zwischen 0 (nicht beliebt) und 10 (extrem beliebt).
# Ich würde sagen, dass Ramy Bensebainin bei den Fans in der Bundesliga eine Beliebtheit von 7 erreicht. Er ist ein wichtiger Spieler für seinen Verein Eintracht Frankfurt und bekannt für seine Offensivstärke und seine defensiven Fähigkeiten. Zudem hat er auch einige Tore gesetzt, was sein Ansehen bei den Fans noch gesteigert hat.
# Wie beliebt ist Julian Ryerson mit der Spielernummer 26 und der Liga Bundesliga bei den Fans? Antworte nur mit einer Zahl zwischen 0 (nicht beliebt) und 10 (extrem beliebt).
#