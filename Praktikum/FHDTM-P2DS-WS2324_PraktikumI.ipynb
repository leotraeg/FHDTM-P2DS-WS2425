# %% [markdown]
# # Programmierkurs 2 Data Science (WS23/24)
# Praktikum I: Python I+II+III und NumPy
#
# *   Eigenständige Erarbeitung und Abgabe zu zweit oder individuell.
# *   Abgabe über Ilias als .ipynb file mit kompilierter Ausgabe.
# *   Abgabefrist siehe Ilias.
# *   Nicht kompilierter Code wird nicht bewertet.
# *   Bei allen Codingaufgaben bitte ich Sie, die finale Datenstrukturen auszugeben/anzuzeigen und einen inline-Kommentar mit dem Aufgabenkürzel in die oberste Code Zelle hinzuzufügen `#(a)`.
# *   Bitte die Dokumentenstruktur und Aufgabenstellung beibehalten: Sie können jedoch beliebig viele Code oder Text Zellen für die Bearbeitung der Aufgaben hinzufügen.
# *   Ich kann nicht ausschließen, dass Sie LLMs zur Bearbeitung dieser Aufgaben verwenden. Alle Freitext Aufgaben können in der Regel sehr knapp in eigenen Worten auf Grundlage der Vorlesungsfolien und der offiziellen Python Documentation beantwortet werden. Bei den Programmieraufgaben profitieren Sie ebenfalls von einer eigenständigen Bearbeitung. Sollten Sie LLMs verwenden wenn für die Aufgabenbearbeitung entweder die Vorlesungsfolien oder die offizielle Python Documentation unzureichend, behandeln Sie diese bitte wie Quellen aus dem Internet (Zitieren).
# ---

# %% [markdown]
# ## Python I

# %% [markdown]
# (a) [2 Punkte] Beschreiben Sie dynamisch typisierte Programmiersprachen an dem Beispiel von Python in ihren eigenen Worten. Legen Sie zur Veranschaulichung Datenvariablen mit Wertezuweisungen und Veränderungen an. Den Typ einer Variable können Sie mittels `type()` Funktion ausgeben.
#
# ---

# %% [markdown]
# (b) [2 Punkte] Erläutern Sie in eigenen Worten die Vor- und Nachteile von dynamischen und statischen typisierten Programmiersprachen.
#
# ---

# %% [markdown]
# (c) [1 Punkt] Welche Unanhemlichkeiten könnten Ihrer Meinung nach passieren, wenn Sie einen Datensatz aus einer .csv Datei oder Datenbank auslesen und dabei auf die automatisierte dynamische Typisierung vertrauen?

# %% [markdown]
# ---

# %% [markdown]
# ##Python II
# In den folgenden Abschnitten werden Sie Gebrauch von der Names-Bibliothek gebrauch machen, welche randomisiert Namen ausgibt: https://pypi.org/project/names/
# *   `names.get_full_name()` liefert einen zusammengesetzten Vor- und Nachnamen.
# *   `names.get_first_name()` liefert einen Vornamen.
# *  ` names.get_last_name()` liefert einen Nachnamen.
# ---

# %% [markdown]
# *   (a.1) [1 Punkt] Installieren und importieren Sie die `names` Bibliothek.
# *   (a.2) [1 Punkt] Erzeugen Sie eine Liste  `list_names` mit hundert (100) zusammengesetzten Vor- und Nachnamen.
#
# ---

# %% [markdown]
# (b) [1 Punkt] Geben Sie die letzten zehn (10) Namen der `list_names` mittels Slicing Ausdruck aus.
#
# ---

# %% [markdown]
# (c) [1 Punkt] Fügen Sie ihren Vor- und Nachnamen (ggf. zusätzlich ihres Praktikumpartners) der Liste an die erste Stelle(n) der Liste `list_names` hinzu. Sie können das Einfügen eines neuen Eintrages eigenständig nachprogramieren oder eine geignete Methode unter https://docs.python.org/3/tutorial/datastructures.html aussuchen und verwenden. Vergewissern Sie sich jedoch, dass sich die Menge der Einträge innerhalb `list_names` entsprechend erhöht.
#
# ---

# %% [markdown]
# Erzeugen Sie eine Liste namens `list_names_abbreviations` abgeleitet von der `list_names`. Der erste Buchstabe des Vor- und Nachnamen von beispielsweise `'Betty Williams'` wandelt in die Abkürzung `'B.W.'` um. Diese Aufgabe unterteilt sich in zwei Unteraufgaben:
# *   (d.1) [2 Punkte] Legen Sie eine Funktion zur Generierung einer Abkürzung an.
# *   (d.2) [1 Punkte] Prägen Sie mithilfe der vorherigen Funktion und `list_names` über eine List Comprehsion die neue Liste `list_names_abbreviations` aus.
#
# ---

# %% [markdown]
# Sie können für diese Aufgaben mehrere Collections benutzen. Empfehlung: Machen Sie sich die Eigenschaft der Python Collection zu Nutze, welche keine Duplikate erlaubt. Sie können ihren Algorithmus beliebig komplex gestalten bsp. O(N*N).
# *   (e.1) [3 Punkte] Geben Sie eine Collection `list_names_abbreviations_duplicates` mit allen duplizierten Einträgen der Liste `list_names_abbreviations` mit reiner Python Programmierung ohne Hilfsbibliotheken aus. Geben Sie die Anzahl der Elemente des Containers aus.
# *   (e.2) [2 Punkte] Geben Sie eine Collection `list_names_abbreviations_unique` mit allen Einträgen ohne Duplikate der Liste `list_names_abbreviations` mit reiner Python Programmierung ohne Hilfsbibliotheken aus. Geben Sie die Anzahl der Elemente des Containers aus. Hinweis: Die Duplikate kommen in diesem Container nur einmal vor.
#
# Hinweis: Sollte `list_names_abbreviations` über keine Duplikate verfügen, bitte ich Sie in (a) nochmals neue Namen zu generieren.
#
# ---

# %% [markdown]
# (f.1) [4.5 Punkte] Erzeugen Sie ein dictionary Container `dict_names` mit den Abkürzungen der `list_names_abbreviations_unique` als `key` und entsprechende Einträge der `list_names` als List-Container als `value`. Helfen Sie sich gerne mit den angelegten Datenstrukturen aus den vorherigen Aufgaben. Hinweis: die Methode `enumerate(list)` liefert ihnen den Index und den Eintrag beim Durchlaufen einer Schleife.
#
# Beispiel Output mit drei Namen:
# ```
# {'C.D.': ['Connie Delapaz'],
#  'L.T.': ['Leo Traeger', 'Louis Tiger']}
# ```
#
# (f.2) [0.5 Punkte] Geben Sie alle Namen zu ihrem persönlichen Kürzel des dictionaries aus.
#
# ---

# %% [markdown]
# Map, Reduce, Filter
# *   (g.1) [1 Punkt] Erklären Sie kurz die Funktion der `.map ` Methode und setzen Sie damit die Aufgabenstellung in Python II (d) wiederholt um.
# *   (g.2) [2 Punkt] Nennen Sie kurz den Vorteil der `.map` , `.reduce` oder `.filter` Methode durch Aufzeigen eines Beispiels zur kaskadierenden Benutzung des map Objekts.
#
#
# ---

# %% [markdown]
# ##Python III

# %% [markdown]
# (a) [3 Punkte] Geben Sie ein Beispiel für imperative und deklarative Programmierung in Python. Sie können zur Veranschaulichung ein Coding Beispiel erstellen.
#
# ---

# %% [markdown]
# In dieser Aufgabe sollen Sie eine Klasse über Studierende erstellen.
#
# *   (b.1) [4 Punkte] Die Klasse `student` enthält die Attribute `name`, `id`, `campus`, `semester`, `degree`, `program`. Schreiben Sie eine Konstruktor Methode `__init__(self)` mit `semester=1`als default-Wert.
# *   (b.2) [2 Punkte] Die Klasse soll die Methode `total_tuition` enthalten, welche die Anzahl der Semester mit einer Klassenvariable `global_tuition` (= 350)  multipliziert und ausgibt.
# *   (b.3) [2 Punkte] Die Klasse soll die `property` Methode `total_credits` enthalten, welche im Falle von `degree` 'Bachelor' 180 und 'Master' 120 ausgibt.
# *   (b.4) [2 Punkte] Erzeugen Sie sich selber und vier (4) weitere Studierende durch Instanzierung der Klasse `student` und speichern Sie diese in einer Python Liste `student_object_list`.
# *   (b.5) [2 Punkt] Geben Sie alle Namen, bereits bezahlte Studiengebühren, und Credits der Studierenden aus der `student_object_list` aus.
#
# ---

# %% [markdown]
# Unterklasse
# *   (c.1) [3 Punkte] Erstellen Sie die Unterklasse international_student mit den zusätzlichen Attributen `home_country` und `language_proficiency`. Sie können die `super()` Funktion für die Instanziierung der originalen Attribute der Klasse `student` verwenden. Überschreiben Sie die property `total_credits` Methode der Klasse `student` und geben Sie regulär 30 für internationale Studierende aus.
# *   (c.2) [2 Punkte] Instanzieren Sie zwei internationale Studierende und geben Sie den Namen, Credits und das Herkunftsland aus.
# ---

# %% [markdown]
# ##Python NumPy

# %% [markdown]
# (a) [3 Punkte] Geben Sie ein Beispiel für die Datentypisierung innerhalb von Listen (Python Container) und NumPy. Nennen Sie Vor- und Nachteile. Sie können zur Veranschaulichung ein Coding Beispiel erstellen.
#
# ---

# %% [markdown]
# Zwei-dimensionalen NumPy Arrays, Masking:
# *   (b.1) [1 Punkt] Erstellen Sie ein 6x4 NumPy Array namens `A` welches zufällige Integer Zahlen von 1 bis zehn (10) enthält. Hinweis: Verwenden Sie gerne die `reshape` Methode.
# *   (b.2) [1 Punkt] Finden Sie alle Zahlen, welche größer als fünf (5) sind und multiplizieren diese mit zehn (10). Nennen Sie das neue Array `B`.
# *   (b.3) [1 Punkt] Ersetzen Sie innerhalb von `B` das Element in der zweiten Reihe und dritten Spalte mit dem Wert -10.
# *   (b.4) [1 Punkt] Multiplizieren Sie alle Elemente der zweiten Reihe mal 3 (drei).
#
# ---

# %% [markdown]
# SciPy
# *   (c.1) [1 Punkt] Beschreiben Sie kurz in eigenen Worten, worauf die SciPy Bibliothek aufbaut und welchen Vorteil sie bietet.
# *   (c.2) [4 Punkte] Die Cosine-Similarity ist eine von vielen Metriken für die Bestimmung von Ähnlichkeiten zwischen Vektoren. Berechnen Sie die Ähnlichkeit zwischen den Vektoren `student = [-1,0,-5,3,6]`, `soccer = [5,-2,3,-5,6]` und `festival = [-4,3,1,0,3] ` mittels der SciPy Bibliothek (https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.distance.cosine.html) und interpretieren Sie anhand der Cosine-Similarity, ob Fußball oder Festivals interessanter für Studierende sind.
#
# ![image.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# Structured Array, Masking, Aggregation und Sortierung
#
# *   (d.1) [3 Punkte] Legen Sie die untenstehende Tabelle als Structured Array `Bundeskanzler` an. Vergeben Sie sinnvolle Datentypen für die Attribute und geben Sie das Structured Array aus.
# *   (d.2) [1 Punkt] Geben Sie `Bundeskanzler` absteigend sortiert nach der Amtszeit aus. Hinweis: Verwenden Sie Masking.
# *   (d.3) [1 Punkt] Geben Sie alle Namen von `Bundeskanzler` aus, welche eine ungerade Anzahl von Amtsjahren regiert haben. Hinweis: modulo `%`
# *   (d.4) [1 Punkt] Geben Sie jeweils den Durchschnitt der Regierungsjahre von den zwei Parteien `schwarz` und `rot` an.
# *   (d.5.1) [0.5 Punkte] Welche Bundeskanzler kämen in Frage, einen sogenannten statistischen Ausreißer (Outlier) darzustellen?
# *   (d.5.2) [1.5 Punkte] Welche Annahme beim Kodieren und Dekodieren (Data Literacy Ethics) des untenstehenden Datensatzes in Bezug auf `amtszeit_jahre` könnten zu einer ungünstigen Interpretation führen? Nennen Sie ein Beispiel, welcher Kontext fehlen könnte.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
